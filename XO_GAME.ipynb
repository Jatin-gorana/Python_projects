# %%
# # GameBoard class created
# class Gameboard:
#     def __init__(self):
#         self.game_board = {1:' ', 2:' ', 3:' ', 4:' ', 5:' ', 6:' ', 7:' ', 8:' ', 9:' '}
#     def set_items(self,user, position, game_board):
#         game_board[position] = user
#         return game_board
#     @property
#     def gameboard(self):
#         return self.game_board
#     def clearboard(self):
#         self.game_board = {1:' ', 2:' ', 3:' ', 4:' ', 5:' ', 6:' ', 7:' ', 8:' ', 9:' '}
#     def is_take_place(self, game_board, index):
#         if game_board[index] != ' ':
#             return True
#     def is_board_full(self, game_board):
#         for index in range(1,10):
#             if game_board[index] == ' ':
#                 return False
#         return True
#     def is_game_won(self, game_board):
#         win_conds = ((1,2,3), (4,5,6), (7,8,9), (1,4,7), (2,5,8), (3,6,9), (1,5,9), (3,5,7))
#         for win_cond in win_conds: 
#             if game_board[win_cond[0]] == game_board[win_cond[1]] and game_board[win_cond[1]] == game_board[win_cond[2]] and game_board[win_cond[0] != ' ']:
#                 return True
#     def print_board(self, game_board):
#         index = 0
#         for row in range(1,4):
#             for column in range(1,4):
#                 index += 1
#                 if column != 3:
#                     print(game_board[index], endl='')
#                     print('|', endl='')
#                 else:
#                     print(game_board[index])

# %%
# class Game():
#     def game_start(self):
#         self.controlboard = Gameboard()
#         self.game_board = self.controlboard.gameboard
#         self.playerone = 'O'
#         self.playertwo = 'X'
#         print("--------Welcome to X-O game--------")
#         print("Please enter player 1's name")
#         self.player_one = input(': ')
#         print("Please enter player 2's name")
#         self.player_two = input(': ')
#         print("Here is your game_board, each place is represented by 1-9, starting from left column each time and moving along the row")
#         self.controlboard.print_board(self.game_board)
#         self.turn = 1
#     def game_end(self):
#         if self.game_running == False:
#             replay = input("Press 0 to quit or 1 to play again: ")
#             try:
#                 if int(replay):
#                     self.game_running = True
#                     self.game_start()
#             except:
#                 print("A number must be entered.")
#                 self.game_end()
#     def take_turn(self, user, item):
#         print(user + " choose a place, 1-9")
#         try:
#             position = int(input(': '))
#             if position>9 or position < 1:
#                 raise Exception
#         except: 
#             print('Pick a number between 1-9')
#             return self.taketurn(user, item)
        
#         if self.controlboard.is_place_taken(self.game_board, position):
#             print("That place is taken")
#             self.taketurn(user,item)
#         else:
#             self.controlboard.set_items(item, position, self.game_board)
#             self.controlboard.printboard(self.game_board)
#             if self.controlboard.is_game_won(self.game_board):
#                 print(user + " wins!!!")
#                 self.game_running = False
                
#     def main(self, ):
#         self.game_running = True
#         self.game_start()
#         while self.game_running:
#             if self.turn%2 != 0:
#                 self.taketurn(self.playerone, 'O')
#             else:
#                 self.taketurn(self.playertwo, 'X')
                
#             if self.controlboard.is_board_full(self.game_board):
#                 print("Its a draw!! You both lose!")
#                 self.game_running = False
#             self.turn += 1
        
#             if not self.game_running:
#                 self.game_end()
                
# if __name__ == '__main__':
#     Game().main()

# %%
class Gameboard:
    def __init__(self):
        self.game_board = {1: ' ', 2: ' ', 3: ' ', 4: ' ', 5: ' ', 6: ' ', 7: ' ', 8: ' ', 9: ' '}

    def set_items(self, user, position, game_board):
        game_board[position] = user
        return game_board

    @property
    def gameboard(self):
        return self.game_board

    def clearboard(self):
        self.game_board = {1: ' ', 2: ' ', 3: ' ', 4: ' ', 5: ' ', 6: ' ', 7: ' ', 8: ' ', 9: ' '}

    def is_take_place(self, game_board, index):
        if game_board[index] != ' ':
            return True

    def is_board_full(self, game_board):
        for index in range(1, 10):
            if game_board[index] == ' ':
                return False
        return True

    def is_game_won(self, game_board):
        win_conds = ((1, 2, 3), (4, 5, 6), (7, 8, 9), (1, 4, 7), (2, 5, 8), (3, 6, 9), (1, 5, 9), (3, 5, 7))
        for win_cond in win_conds:
            if (
                game_board[win_cond[0]] == game_board[win_cond[1]]
                and game_board[win_cond[1]] == game_board[win_cond[2]]
                and game_board[win_cond[0]] != ' '
            ):
                return True

    def print_board(self, game_board):
        index = 0
        for row in range(1, 4):
            for column in range(1, 4):
                index += 1
                if column != 3:
                    print(game_board[index], end='')
                    print('|', end='')
                else:
                    print(game_board[index])

# %%
class Game:
    def game_start(self):
        self.controlboard = Gameboard()
        self.game_board = self.controlboard.gameboard
        self.playerone = 'O'
        self.playertwo = 'X'
        print("--------Welcome to X-O game--------")
        print("Please enter player 1's name")
        self.player_one = input(': ')
        print("Please enter player 2's name")
        self.player_two = input(': ')
        print("Here is your game_board, each place is represented by 1-9, starting from left column each time and moving along the row")
        self.controlboard.print_board(self.game_board)
        self.turn = 1

    def game_end(self):
        if not self.game_running:
            replay = input("Press 0 to quit or 1 to play again: ")
            try:
                if int(replay):
                    self.game_running = True
                    self.game_start()
            except:
                print("A number must be entered.")
                self.game_end()

    def take_turn(self, user, item):
        print(user + " choose a place, 1-9")
        try:
            position = int(input(': '))
            if position > 9 or position < 1:
                raise Exception
        except:
            print('Pick a number between 1-9')
            return self.take_turn(user, item)

        if self.controlboard.is_take_place(self.game_board, position):
            print("That place is taken")
            self.take_turn(user, item)
        else:
            self.controlboard.set_items(item, position, self.game_board)
            self.controlboard.print_board(self.game_board)
            if self.controlboard.is_game_won(self.game_board):
                print(user + " wins!!!")
                self.game_running = False

    def main(self):
        self.game_running = True
        self.game_start()
        while self.game_running:
            if self.turn % 2 != 0:
                self.take_turn(self.playerone, 'O')
            else:
                self.take_turn(self.playertwo, 'X')

            if self.controlboard.is_board_full(self.game_board):
                print("It's a draw!! You both lose!")
                self.game_running = False
            self.turn += 1

            if not self.game_running:
                self.game_end()


if __name__ == '__main__':
    Game().main()
# Out:
# --------Welcome to X-O game--------
# Please enter player 1's name
# : 1
# Please enter player 2's name
# : 2
# Here is your game_board, each place is represented by 1-9, starting from left column each time and moving along the row
#  | |
#  | |
#  | |
# O choose a place, 1-9
# : 2
#  |O|
#  | |
#  | |
# X choose a place, 1-9
# : 4
#  |O|
# X| |
#  | |
# O choose a place, 1-9
# : 5
#  |O|
# X|O|
#  | |
# X choose a place, 1-9
# : 6
#  |O|
# X|O|X
#  | |
# O choose a place, 1-9
# : 7
#  |O|
# X|O|X
# O| |
# X choose a place, 1-9
# : 8
#  |O|
# X|O|X
# O|X|
# O choose a place, 1-9
# : 9
#  |O|
# X|O|X
# O|X|O
# X choose a place, 1-9
# : 1
# X|O|
# X|O|X
# O|X|O
# O choose a place, 1-9
# : 3
# X|O|O
# X|O|X
# O|X|O
# O wins!!!
# It's a draw!! You both lose!
# Press 0 to quit or 1 to play again: 0
